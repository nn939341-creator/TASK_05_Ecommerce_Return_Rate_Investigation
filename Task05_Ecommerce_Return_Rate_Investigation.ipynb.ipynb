# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Ecommerce_Return_Rate_Dataset_500Rows.csv")

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ...  Amount    ship-city   ship-state  ship-postal-code  \
# ...

# %%
df.shape
# Out:
# (500, 25)

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22', 'Return Rate'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               500 non-null    int64
#  1   Order ID            500 non-null    object
#  2   Date                500 non-null    object
#  3   Status              500 non-null    object
#  4   Fulfilment          500 non-null    object
#  5   Sales Channel       500 non-null    object
#  6   ship-service-level  500 non-null    object
#  7   Style               500 non-null    object
#  8   SKU                 500 non-null    object
#  9   Category            500 non-null    object
#  10  Size                500 non-null    object
#  11  ASIN                500 non-null    object
#  12  Courier Status      483 non-null    object
#  13  Qty                 500 non-null    int64
#  14  currency            475 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# index                   0
# Order ID                0
# Date                    0
# Status                  0
# Fulfilment              0
# Sales Channel           0
# ship-service-level      0
# Style                   0
# SKU                     0
# Category                0
# Size                    0
# ASIN                    0
# Courier Status         17
# Qty                     0
# currency               25
# Amount                 25
# ship-city               0
# ship-state              0
# ship-postal-code        0
# ship-country            0
# promotion-ids         164
# B2B                     0
# fulfilled-by          394
# Unnamed: 22           500
# Return Rate             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
len(df)
# Out:
# 500

# %%
(df["Return Rate"] > 0.5).sum()
# Out:
# np.int64(17)

# %%
((df["Return Rate"] > 0.5).mean()) * 100
# Out:
# np.float64(3.4000000000000004)

# %%
df.mean(numeric_only=True)
# Out:
# index                  249.500000
# Qty                      0.922000
# Amount                 620.763389
# ship-postal-code    483601.282000
# B2B                      0.004000
# Unnamed: 22                   NaN
# Return Rate              0.142340
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# index                  249.50
# Qty                      1.00
# Amount                 563.00
# ship-postal-code    500075.00
# B2B                      0.00
# Unnamed: 22               NaN
# Return Rate              0.11
# dtype: float64

# %%
df.std(numeric_only=True)
# Out:
# index                  144.481833
# Qty                      0.275805
# Amount                 279.438816
# ship-postal-code    191737.126666
# B2B                      0.063182
# Unnamed: 22                   NaN
# Return Rate              0.136496
# dtype: float64

# %%
df.describe()
# Out:
#             index         Qty       Amount  ship-postal-code  Unnamed: 22  \
# count  500.000000  500.000000   475.000000        500.000000          0.0
# mean   249.500000    0.922000   620.763389     483601.282000          NaN
# std    144.481833    0.275805   279.438816     191737.126666          NaN
# min      0.000000    0.000000     0.000000     110016.000000          NaN
# 25%    124.750000    1.000000   406.000000     400062.750000          NaN
# 50%    249.500000    1.000000   563.000000     500075.000000          NaN
# 75%    374.250000    1.000000   744.000000     600073.000000          NaN
# max    499.000000    2.000000  2130.000000     854301.000000          NaN
#
#        Return Rate
# count   500.000000
# mean      0.142340
# std       0.136496
# min       0.000000
# 25%       0.057500
# 50%       0.110000
# 75%       0.162500
# max       0.910000

# %%
df.groupby("Category")["Return Rate"].mean()
# Out:
# Category
# Blouse           0.120000
# Bottom           0.160000
# Ethnic Dress     0.043333
# Saree            0.050000
# Set              0.143046
# Top              0.148333
# Western Dress    0.186087
# kurta            0.133163
# Name: Return Rate, dtype: float64

# %%
df.groupby("Category")["Return Rate"].mean().plot(kind="bar", figsize=(10,5))
plt.title("Category vs Return Rate")
plt.show()

# %%
plt.hist(df["Return Rate"], bins=10)
plt.title("Return Rate Distribution")
plt.show()

# %%
plt.boxplot(df["Return Rate"])
plt.title("Return Rate Boxplot")
plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()
